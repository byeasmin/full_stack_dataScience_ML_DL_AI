# %% [markdown]
# <a href="https://colab.research.google.com/github/byeasmin/full_stack_dataScience_ML_DL_AI/blob/main/function.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Function
#
#
# 1.   Defining a function
# 2.   Calling a function

# %% [markdown]
# **Define**

# %%
def greet():
  print("Hello")
  print("Hellow")

# %% [markdown]
# **Call**

# %%
greet()
# Out:
# Hello
# Hellow

# %%
greet()
# Out:
# Hello
# Hellow

# %%
def add(): #arguments
